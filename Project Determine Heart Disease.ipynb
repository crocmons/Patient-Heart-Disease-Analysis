# %% [markdown]
# # Project Patient Heart Disease:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv(r'C:\Users\HP\Desktop\ml_project\heart-disease.csv')
df
# Out:
#      age  gender  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63       1   3     145.0  233.0    1        0    150.0      0      2.3
# 1     37       1   2     130.0  250.0    0        1    187.0      0      3.5
# 2     41       0   1     130.0  204.0    0        0    172.0      0      1.4
# 3     56       1   1     120.0  236.0    0        1    178.0      0      0.8
# 4     57       0   0     120.0  354.0    0        1    163.0      1      0.6
# ..   ...     ...  ..       ...    ...  ...      ...      ...    ...      ...
# 298   57       0   0     140.0  241.0    0        1    123.0      1      0.2
# 299   45       1   3     110.0  264.0    0        1    132.0      0      1.2
# 300   68       1   0     144.0  193.0    1        1    141.0      0      3.4
# 301   57       1   0     130.0  131.0    0        1    115.0      1      1.2
# 302   57       0   1     130.0  236.0    0        0    174.0      0      0.0
#
# ...

# %%
df.shape
# Out:
# (303, 17)

# %%
df.head(15)
# Out:
#     age  gender  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63       1   3     145.0  233.0    1        0    150.0      0      2.3
# 1    37       1   2     130.0  250.0    0        1    187.0      0      3.5
# 2    41       0   1     130.0  204.0    0        0    172.0      0      1.4
# 3    56       1   1     120.0  236.0    0        1    178.0      0      0.8
# 4    57       0   0     120.0  354.0    0        1    163.0      1      0.6
# 5    57       1   0     140.0    NaN    0        1    148.0      0      0.4
# 6    56       0   1     140.0  294.0    0        0    153.0      0      1.3
# 7    44       1   1     120.0  263.0    0        1    173.0      0      0.0
# 8    52       1   2     172.0  199.0    1        1      NaN      0      0.5
# 9    57       1   2     150.0  168.0    0        1    174.0      0      1.6
# 10   54       1   0       NaN  239.0    0        1    160.0      0      1.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   gender    303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  302 non-null    float64
#  4   chol      302 non-null    float64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   302 non-null    float64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
#  14  demo1     0 non-null      float64
#  15  demo2     0 non-null      float64
#  16  demo3     0 non-null      float64
# dtypes: float64(7), int64(10)
# memory usage: 40.4 KB

# %%
# drop unrelated/blank columns
df.drop(['demo1', 'demo2', 'demo3'], axis=1, inplace=True)

# %%
df
# Out:
#      age  gender  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63       1   3     145.0  233.0    1        0    150.0      0      2.3
# 1     37       1   2     130.0  250.0    0        1    187.0      0      3.5
# 2     41       0   1     130.0  204.0    0        0    172.0      0      1.4
# 3     56       1   1     120.0  236.0    0        1    178.0      0      0.8
# 4     57       0   0     120.0  354.0    0        1    163.0      1      0.6
# ..   ...     ...  ..       ...    ...  ...      ...      ...    ...      ...
# 298   57       0   0     140.0  241.0    0        1    123.0      1      0.2
# 299   45       1   3     110.0  264.0    0        1    132.0      0      1.2
# 300   68       1   0     144.0  193.0    1        1    141.0      0      3.4
# 301   57       1   0     130.0  131.0    0        1    115.0      1      1.2
# 302   57       0   1     130.0  236.0    0        0    174.0      0      0.0
#
#      slope  ca  thal  target
# ...

# %%
df.head(12)
# Out:
#     age  gender  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63       1   3     145.0  233.0    1        0    150.0      0      2.3
# 1    37       1   2     130.0  250.0    0        1    187.0      0      3.5
# 2    41       0   1     130.0  204.0    0        0    172.0      0      1.4
# 3    56       1   1     120.0  236.0    0        1    178.0      0      0.8
# 4    57       0   0     120.0  354.0    0        1    163.0      1      0.6
# 5    57       1   0     140.0    NaN    0        1    148.0      0      0.4
# 6    56       0   1     140.0  294.0    0        0    153.0      0      1.3
# 7    44       1   1     120.0  263.0    0        1    173.0      0      0.0
# 8    52       1   2     172.0  199.0    1        1      NaN      0      0.5
# 9    57       1   2     150.0  168.0    0        1    174.0      0      1.6
# 10   54       1   0       NaN  239.0    0        1    160.0      0      1.2
# ...

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    1
# chol        1
# fbs         0
# restecg     0
# thalach     1
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)

# %%
df.head(15)
# Out:
#     age  gender  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63       1   3     145.0  233.0    1        0    150.0      0      2.3
# 1    37       1   2     130.0  250.0    0        1    187.0      0      3.5
# 2    41       0   1     130.0  204.0    0        0    172.0      0      1.4
# 3    56       1   1     120.0  236.0    0        1    178.0      0      0.8
# 4    57       0   0     120.0  354.0    0        1    163.0      1      0.6
# 6    56       0   1     140.0  294.0    0        0    153.0      0      1.3
# 7    44       1   1     120.0  263.0    0        1    173.0      0      0.0
# 9    57       1   2     150.0  168.0    0        1    174.0      0      1.6
# 11   48       0   2     130.0  275.0    0        1    139.0      0      0.2
# 12   49       1   1     130.0  266.0    0        1    171.0      0      0.6
# 13   64       1   3     110.0  211.0    0        0    144.0      1      1.8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       300 non-null    int64
#  1   gender    300 non-null    int64
#  2   cp        300 non-null    int64
#  3   trestbps  300 non-null    float64
#  4   chol      300 non-null    float64
#  5   fbs       300 non-null    int64
#  6   restecg   300 non-null    int64
#  7   thalach   300 non-null    float64
#  8   exang     300 non-null    int64
#  9   oldpeak   300 non-null    float64
#  10  slope     300 non-null    int64
#  11  ca        300 non-null    int64
#  12  thal      300 non-null    int64
#  13  target    300 non-null    int64
# dtypes: float64(4), int64(10)
# memory usage: 35.2 KB

# %%
#change data type
df['chol'] = df['chol'].astype('int')

# %%
df['chol'].dtypes
# Out:
# dtype('int32')

# %%
#check columns name
df.columns
# Out:
# Index(['age', 'gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['oldpeak'] = df['oldpeak'].astype('int')
df['oldpeak'].dtypes
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       300 non-null    int64
#  1   gender    300 non-null    int64
#  2   cp        300 non-null    int64
#  3   trestbps  300 non-null    float64
#  4   chol      300 non-null    int32
#  5   fbs       300 non-null    int64
#  6   restecg   300 non-null    int64
#  7   thalach   300 non-null    float64
#  8   exang     300 non-null    int64
#  9   oldpeak   300 non-null    int32
#  10  slope     300 non-null    int64
#  11  ca        300 non-null    int64
#  12  thal      300 non-null    int64
#  13  target    300 non-null    int64
# dtypes: float64(2), int32(2), int64(10)
# memory usage: 32.8 KB

# %%
# rename columns
df.rename(columns={'ca':'calc'})
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63       1   3     145.0   233    1        0    150.0      0        2
# 1     37       1   2     130.0   250    0        1    187.0      0        3
# 2     41       0   1     130.0   204    0        0    172.0      0        1
# 3     56       1   1     120.0   236    0        1    178.0      0        0
# 4     57       0   0     120.0   354    0        1    163.0      1        0
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0     140.0   241    0        1    123.0      1        0
# 299   45       1   3     110.0   264    0        1    132.0      0        1
# 300   68       1   0     144.0   193    1        1    141.0      0        3
# 301   57       1   0     130.0   131    0        1    115.0      1        1
# 302   57       0   1     130.0   236    0        0    174.0      0        0
#
#      slope  calc  thal  target
# ...

# %%
# describe() method returns description of the data in the dataframe(i.e. count)
df.describe()
# Out:
#               age      gender          cp    trestbps        chol         fbs  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean    54.366667    0.680000    0.970000  131.433333  246.626667    0.146667
# std      9.125228    0.467256    1.032466   17.456076   51.920643    0.354364
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.500000    1.000000    1.000000  130.000000  241.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.523333  149.576667    0.330000    0.770000    1.396667    0.736667
# ...

# %%
# use describe() for specific columns
df[['age', 'cp', 'exang']].describe()
# Out:
#               age          cp       exang
# count  300.000000  300.000000  300.000000
# mean    54.366667    0.970000    0.330000
# std      9.125228    1.032466    0.470998
# min     29.000000    0.000000    0.000000
# 25%     47.000000    0.000000    0.000000
# 50%     55.500000    1.000000    0.000000
# 75%     61.000000    2.000000    1.000000
# max     77.000000    3.000000    1.000000

# %% [markdown]
# # EDA ( Exploratory Data Analysis )

# %% [markdown]
# ### Gender

# %%
# plotting a scatter chart or catplot chart for Gender and it's count
sns.set_theme(style='whitegrid')
ax = sns.countplot(x='gender', data=df)

for chart in ax.containers:
    ax.bar_label(chart)

# %%
# plotting a bar chart for age vs total amount
sns.set_theme()
disease = df.groupby(['age'], as_index=False)['thalach'].sum().sort_values(by='thalach', ascending=False)
sns.scatterplot(x='age', y='thalach', data=disease, hue='age');

# %% [markdown]
# Above data shown the thalach for heart-disease

# %% [markdown]
# ## Age

# %%
heart_disease = df.groupby(['age'], as_index=False)['cp'].sum().sort_values(by='cp', ascending=False)
sns.set(rc={'figure.figsize':(20, 6)})
sns.barplot(x='age', y='cp', data=heart_disease);

# %%
ax = sns.countplot(data=df, x='age');
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ## State

# %%
# trestbps
stateof_disease = df.groupby(['target'], as_index=False)['trestbps'].sum().sort_values(by='trestbps', ascending=False)
sns.set_theme(style='whitegrid')
sns.lmplot(data=stateof_disease, x='trestbps', y='target');

# %%
fig1, ax1 = plt.subplots(figsize=(12, 7))
df.groupby('gender')['slope'].sum().nlargest(10).sort_values(ascending=False).plot(kind='pie');

# %%
df.head(12)
# Out:
#     age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63       1   3     145.0   233    1        0    150.0      0        2
# 1    37       1   2     130.0   250    0        1    187.0      0        3
# 2    41       0   1     130.0   204    0        0    172.0      0        1
# 3    56       1   1     120.0   236    0        1    178.0      0        0
# 4    57       0   0     120.0   354    0        1    163.0      1        0
# 6    56       0   1     140.0   294    0        0    153.0      0        1
# 7    44       1   1     120.0   263    0        1    173.0      0        0
# 9    57       1   2     150.0   168    0        1    174.0      0        1
# 11   48       0   2     130.0   275    0        1    139.0      0        0
# 12   49       1   1     130.0   266    0        1    171.0      0        0
# 13   64       1   3     110.0   211    0        0    144.0      1        1
# ...

# %%
# create a histogram of the age column with 50 bins
df['age'].plot.hist(bins=50);

# %%
# call pandas plot.hist() on the entire df and toggle the 'subplots' parameter to true
df.plot.hist(figsize=(10,25), subplots=True);

# %% [markdown]
# Now Let's try to compare two variables vs the target variable

# %% [markdown]
# More Specifically we'll see how age and trestbps combined effect the target in patients over 50 years old.

# %%
# create dataframe with patients over 50 years old
sns.set_theme(style='whitegrid')
over_50_years = df[df['age'] > 50]

# we create the plt here:
fig, ax = plt.subplots(figsize=(10, 6))

# I'm using scatter plot for this data:
scatter = ax.scatter(
        over_50_years['age'],
        over_50_years['trestbps'],
        c = over_50_years['target']     
)
# Customize the plot here:
ax.set(title='Heart Disease and Patients Blood Pressure Levels',
       xlabel='age',
       ylabel='Blood Pressure'
      );
ax.legend(*scatter.legend_elements(), title='Target')

# Add a meanline - (average) here:
ax.axhline(over_50_years['trestbps'].mean(),
           linestyle=':'
          );

# %% [markdown]
# now change some styles here in the plot:

# %%
# check what styles are available under plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
# Reproduce the same figure as above with the "grayscale" style

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50_years["age"], 
                     over_50_years["chol"], 
                     c=over_50_years["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax.axhline(over_50_years["chol"].mean(),
           linestyle=":");

# %% [markdown]
# change the dot color so that the data point makes more visible and clear

# %% [markdown]
# let's change the cmap parameter of scatter() plot as well as the color parameter of axhline() to fix it.

# %% [markdown]
# ### Replot the same figure as above except change the cmap parameter of scatter() to 'winter'
# #### Also change the color param of axhline() to 'red'

# %%
# create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# plot this data:
scatter = ax.scatter(
    over_50_years['age'],
    over_50_years['chol'],
    c=over_50_years['target'],
    cmap='winter'
)

# customize the dataplot
ax.set(title='Heart Disease and Cholesterol Levels',
       xlabel = 'Age',
       ylabel = 'Cholesterol'
      );

ax.legend(*scatter.legend_elements(), title='Target')

#Add a meanline:
ax.axhline(over_50_years['chol'].mean(),
          linestyle=':',
          color = 'orange'
          );

# %% [markdown]
# ## Save the current figure using savefig()

# %%
fig.savefig('heart-disease.png')

# %% [markdown]
# #### Reset the figure by calling plt.subplots()

# %%
fig, ax = plt.subplots();

# %% [markdown]
# ## --- Finish ---
